# %% [markdown]
# #### Author : Rahul Bhoyar

# %% [markdown]
# In this small tutorial, we will explore the Kaggle CLI tools.

# %% [markdown]
# 1. Installing the kaggle library.

# %%
# !pip install --upgrade --force-reinstall --no-deps kaggle
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.6/84.6 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.6-py3-none-any.whl size=111943 sha256=14bd7cffc3d41f18e722660206d8824d69b865316074e75ce05e7ab71908b033
#   Stored in directory: /root/.cache/pip/wheels/53/34/8c/8ca3450d17206d9e37e1ee3aeb47cbb2873d22a9e0c60eb137
# Successfully built kaggle
# ...
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.5.16
#     Uninstalling kaggle-1.5.16:
#       Successfully uninstalled kaggle-1.5.16
# ...

# %% [markdown]
# Load the kaggle.json which has the access Kaggle API key access.
#
# Set it as a environment variable.

# %%
import os
os.environ['KAGGLE_USERNAME'] = "rrb8695"  #Enter your KAGGLE_USERNAME
os.environ['KAGGLE_KEY'] = "699545fff22498e89391c9b752d43f95"  # Enter you kaggle API Key

# %% [markdown]
# Now, you should be able to use the Kaggle API without specifying the username and key

# %% [markdown]
# To check the Kaggle Version

# %%
# !kaggle -v
# Out:
# Kaggle API 1.6.6

# %% [markdown]
# 2. To check all the kaggle competitions.

# %%
# !kaggle competitions list
# Out:
# ref                                                                              deadline             category            reward  teamCount  userHasEntered
# -------------------------------------------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# https://www.kaggle.com/competitions/home-credit-credit-risk-model-stability      2024-05-06 23:59:00  Featured          $105,000        950           False
# https://www.kaggle.com/competitions/pii-detection-removal-from-educational-data  2024-04-23 23:59:00  Featured           $60,000        970           False
# https://www.kaggle.com/competitions/hms-harmful-brain-activity-classification    2024-04-08 23:59:00  Research           $50,000       1585           False
# https://www.kaggle.com/competitions/playground-series-s4e2                       2024-02-29 23:59:00  Playground            Swag       2168           False
# ...

# %% [markdown]
# 3. To check all the datasets.

# %%
# !kaggle datasets list
# Out:
# ref                                                         title                                              size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# nelgiriyewithana/apple-quality                              Apple Quality                                     170KB  2024-01-11 14:31:07          15320        349  1.0
# bhavikjikadara/google-play-store-applications               Google Play Store Applications                    328KB  2024-02-13 06:48:02            958         28  1.0
# imyjoshua/average-time-spent-by-a-user-on-social-media      Average Time Spent By A User On Social Media       11KB  2024-01-18 10:18:03           2850         39  1.0
# ...

# %% [markdown]
# 4. To check the specific datasets

# %%
# !kaggle datasets list -s "Covid"
# Out:
# ref                                                title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# imdevskp/corona-virus-report                       COVID-19 Dataset                                     19MB  2020-08-07 03:47:47         302162       2252  1.0
# meirnizri/covid19-dataset                          COVID-19 Dataset                                      5MB  2022-11-13 15:47:17          41550        714  1.0
# sudalairajkumar/covid19-in-india                   COVID-19 in India                                   758KB  2021-08-11 04:14:10         230373       1955  0.9117647
# ...

# %% [markdown]
# 5. To see other commands available for dataset.

# %%
# !kaggle datasets list -h
# Out:
# usage: kaggle datasets list [-h] [--sort-by SORT_BY] [--size SIZE] [--file-type FILE_TYPE]
#                             [--license LICENSE_NAME] [--tags TAG_IDS] [-s SEARCH] [-m]
#                             [--user USER] [-p PAGE] [-v] [--max-size MAX_SIZE]
#                             [--min-size MIN_SIZE]
#
# options:
#   -h, --help            show this help message and exit
#   --sort-by SORT_BY     Sort list results. Default is 'hottest'. Valid options are 'hottest', 'votes', 'updated', and 'active'
#   --size SIZE           DEPRECATED. Please use --max-size and --min-size to filter dataset sizes.
#   --file-type FILE_TYPE
#                         Search for datasets with a specific file type. Default is 'all'. Valid options are 'all', 'csv', 'sqlite', 'json', and 'bigQuery'. Please note that bigQuery datasets cannot be downloaded
#   --license LICENSE_NAME
# ...

# %% [markdown]
# **Conclusion :**
#
#
# We can access the kaggle datasets using Kaggle CLI tool.
